# %% [markdown]
# ## 0.Librerías

# %%
import os
import pandas as pd
import time

import numpy as np
from tqdm import tqdm
#from skimage.io import imread, imshow
#from skimage.transform import resize
import matplotlib.pyplot as plt
import datetime
import cv2
#Metricas
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report,ConfusionMatrixDisplay
# %env SM_FRAMEWORK=tf.keras
# Librerias para constuir la arquitectura U-Net
from tensorflow.keras.layers import Input, Lambda, Conv2D, Dropout, MaxPooling2D, Conv2DTranspose, concatenate, MaxPool2D
from tensorflow.keras.models import Model
#import segmentation_models as sm
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf
# Out:
# env: SM_FRAMEWORK=tf.keras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Cambia el directorio de trabajo a la carpeta deseada
os.chdir('/content/drive/MyDrive')
os.listdir()
# Out:
# Mounted at /content/drive
# ['Colab Notebooks',
#  'buildings_png',
#  'build_models',
#  'roads_png',
#  'road_models',
#  'road_build_models',
#  'build_models_custom',
#  'Multiclass_img',
#  'road_models_custom']

# %%
# Mostramos la imagen y su mascara asociada
m=18
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
img=cv2.imread('buildings_png/train/22679020_15.png')[:,:,:3]
plt.imshow(img)
plt.subplot(1,2,2)
img=cv2.imread('roads_png/train_labels/22679020_15.png')[:,:,:3]
plt.imshow(img, cmap='gray')
plt.show()

# %% [markdown]
# # 1.Preprocesado Con cortes

# %% [markdown]
# Como las imagenes son muy grandes (1500x1500) hay dos opciones, podemos reducir su tamaño perdiendo resolucion y calidad de imagen pero manteniendo la info espacial o realizar cortes de tamaño deseado manteniendo así la resolucion en pro de perder esa info espacial por corte. Debido al tamaño pequeño de las construcciones, creo que es más importante tener más resolución.

# %%
def obtener_corte(img,cut=224,tipo='img'):
    """
    FUNCION:    Obtener cortes de una imagen dada de un tamaño (cutxcut)

    PARAMS:
        img: np.array de la imagen por cv2.imread()
        cut: tamaño del corte
        type: indica si es una imagen o su mascara (msk)

    RETURN:
        array_tot: np.array(numero_cortes,cut,cut,canales) donde canales son 3 en las imagenes
        normales y nada en las mascaras

    """
    # Obtener las dimensiones de la imagen (alto, ancho, canales)
    if tipo == 'img':
        alto, ancho, _ = img.shape
        formato=(1,cut,cut,3)
    elif tipo == 'msk':
        alto, ancho= img.shape
        formato=(1,cut,cut)

    # Definir las coordenadas para el recorte
    max_val_recorte=alto-cut
    max_val_recorte_x=ancho-cut
    array_tot=np.array([])
    #bucle ene le eje X
    for j in range(1,int(ancho/cut)+2):
        if cut*j<ancho:
            corte_ini_x=cut*(j-1)
            corte_fin_x=cut*j
        else:
            corte_ini_x=max_val_recorte_x
            corte_fin_x=ancho
        #Bucle en el eje Y
        for i in range(1,int(alto/cut)+2):
            if cut*i<alto:
                corte_ini=cut*(i-1)
                corte_fin=cut*i
            else:
                corte_ini=max_val_recorte
                corte_fin=alto
            # Realizar el recorte de la imagen
            if tipo == 'img':
                trozo_imagen = img[corte_ini:corte_fin, corte_ini_x:corte_fin_x,:]
            elif tipo == 'msk':
                trozo_imagen = img[corte_ini:corte_fin, corte_ini_x:corte_fin_x]
            #agrupar imagenes en un mismo array
            if array_tot.shape[0]>0:
                array_tot=np.vstack([array_tot,trozo_imagen.reshape(formato)])
            else:
                array_tot=trozo_imagen.reshape(formato)
    return array_tot
def num_percentage(img,num=0):
    """
    FUNCION: Devuelve el factor existente entre pixeles de un numero concreto y los pixeles totales de la imagen

    PARAMS:
        img: np.array de la imagen por cv2.imread()

    RETURN:
        num_factor= float pixeles del numero num/ pixeles totales

    """
    total_pixels = img.shape[0] * img.shape[1]
    num_pixels = np.sum(img == num)  # Contar píxeles blancos
    num_factor=num_pixels / total_pixels
    return num_factor
def filter_cut_images(data_path_images, data_path_masks,cut=224,positive_min_mask=0.001,limite=0):
    """
    FUNCION: Dados los directorios donde se encuentran imagenes y mascaras, obtener los recortes de cada una de ellas

    PARAMS:
        data_path_images,data_path_masks: path de imagenes y mascaras
        cut: tamaño del corte
        positive_min_mask: indica el factor minimo de puntos blancos/valores positivos en una mascara. Esto es ideal
            para filtrar imagenes con mucho fondo (valores negativos) vs información (mascara/valores positvos)
        limite: limita el numero de imagenes que se van a procesar. Ideal por si tenemos demasiadas
    RETURN:
        white_factor= float pixeles blancos/ pixeles totales
        final_images: np.array(num,cut,cut,3) array con los resultados de los cortes para las imagenes
        final_masks: np.array(num,cut,cut) array con los resultados de los cortes para las mascaras
    """

    data_list_images = os.listdir(data_path_images)
    data_list_labels = os.listdir(data_path_masks)
    final_images = []
    final_masks = []
    num_img_discard=0
    mask_factors=[]

    #para comprobar que el mismo numero de mascaras que imagenes
    list_exc=[]
    for img in data_list_labels:
      if img not in data_list_images:
        list_exc.append(img)
    data_list_images+=list_exc

    limite = len(data_list_images) if limite == 0 else limite
    for file_name in tqdm(data_list_images[:limite]):
        # Leer la imagen
        data_path_img= 'buildings_png/train' if file_name in list_exc else data_path_images#para las imagenes añadidas
        img = cv2.imread(os.path.join(data_path_img, file_name))[:,:,:3]
        mask_file = os.path.splitext(file_name)[0] + '.png'  # Nombre de la máscara
        mask_path = os.path.join(data_path_masks, mask_file)
        if os.path.exists(mask_path):
            # Leer mascara
            mask = cv2.imread(mask_path)[:,:,1]
            mask_factor=num_percentage(mask,255)
            if mask_factor>positive_min_mask:
                mask_factors.append(mask_factor)
                # Obtener cortes
                img_trozos_imagen=obtener_corte(img,cut,tipo='img')
                #agregar a lista
                img_trozos_list=[trozo for trozo in img_trozos_imagen]
                final_images+=img_trozos_list
                #obtener cortes de la mascara
                mask_trozos_imagen=obtener_corte(mask,cut,tipo='msk')
                #agregar a lista
                mask_trozos_list=[trozo for trozo in mask_trozos_imagen]
                final_masks+=mask_trozos_list
            else:
                num_img_discard+=1
        else:
            num_img_discard+=1
    print(f'Se han descartado {num_img_discard} imagenes')
    # Convertir las listas en arrays NumPy
    final_images = np.asarray(final_images, dtype=np.uint8)
    final_masks = np.asarray(final_masks, dtype=np.uint8)
    #Pasamos valores de 255 a 1
    final_masks[final_masks==255]=1
    mask_factors =np.array(mask_factors)

    return final_images, final_masks, mask_factors

# %%
# Definir las dimensiones de las imágenes
cut=224
white_threshold = 0.1
dire=''
# Directorios de los conjuntos de datos
data_path_train = dire+"roads_png/train"
data_path_train_mask = dire+"roads_png/train_labels"
data_path_test = dire+"roads_png/test"
data_path_test_mask = dire+"roads_png/test_labels"
data_path_val = dire+"roads_png/val"
data_path_val_mask = dire+"roads_png/val_labels"

X_train_pro, Y_train_pro, mask_factors_train = filter_cut_images(data_path_train, data_path_train_mask, cut=cut,limite=110)
print('X_train:', X_train_pro.shape)
print('Y_train:', Y_train_pro.shape)

X_test_pro, Y_test_pro, mask_factors_test = filter_cut_images(data_path_test, data_path_test_mask, cut=cut,limite=10)
print('X_test:', X_test_pro.shape)
print('Y_test:', Y_test_pro.shape)

X_val_pro, Y_val_pro, mask_factors_val = filter_cut_images(data_path_val, data_path_val_mask, cut=cut,limite=0)
print('X_val:', X_val_pro.shape)
print('Y_val:', Y_val_pro.shape)
# Out:
# 100%|██████████| 110/110 [01:00<00:00,  1.81it/s]
# Se han descartado 0 imagenes
# X_train: (5390, 224, 224, 3)
# Y_train: (5390, 224, 224)
# 100%|██████████| 10/10 [00:10<00:00,  1.09s/it]
# Se han descartado 0 imagenes
# X_test: (490, 224, 224, 3)
# Y_test: (490, 224, 224)
# 100%|██████████| 5/5 [00:08<00:00,  1.79s/it]
# Se han descartado 0 imagenes
# X_val: (245, 224, 224, 3)
# Y_val: (245, 224, 224)

# %% [markdown]
# **Nota**: el dataset esta desbalanceado, es decir, el numero de valores positivos (estructuras) detectados en la mascara vs numero de valores negativos no es 50/50. Esto es importante a la hora de evaluar la calidad de los resultados

# %%
df_dat=pd.DataFrame({
    'Train':[mask_factors_train.max(),mask_factors_train.mean(),mask_factors_train.min()],
    'Test':[mask_factors_test.max(),mask_factors_test.mean(),mask_factors_test.min()],
    'Val':[mask_factors_val.max(),mask_factors_val.mean(),mask_factors_val.min()],
},index=['Max','Mean','Min'])
print('Factores asociados a Valores positivos/ Total valores')
display(df_dat)
time.sleep(0.1)
print('Precisiones esperadas en función de los valores positivos')
display(1-df_dat)
# Out:
# Factores asociados a Valores positivos/ Total valores
#          Train      Test       Val
# Max   0.106933  0.074118  0.118369
# Mean  0.054622  0.034094  0.069223
# Min   0.003050  0.005467  0.025168
# Precisiones esperadas en función de los valores positivos
#          Train      Test       Val
# Max   0.893067  0.925882  0.881631
# Mean  0.945378  0.965906  0.930777
# Min   0.996950  0.994533  0.974832

# %% [markdown]
# Por ejemplo, en el entrenamiento, esperamos precisiones mínimas de 0.69 y en donde evolucionen a precisiones superiores al 0.86. Esto ya que al tener un 0.13 (1-0.13=0.86) de media de pixeles blancos un modelo que pusiese todos los valores a 0, obtendría esta precision de 0.86

# %%
# Mostramos la imagen y su mascara asociada
m=18
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.imshow(X_val_pro[m])
plt.subplot(1,2,2)
plt.imshow(Y_val_pro[m], cmap='gray')
plt.show()

# %% [markdown]
# # 2.Entrenamiento

# %%
def double_conv_block(x, n_filters):

   # 2* Conv2D, ReLU activation
   x = Conv2D(n_filters, 3, padding = "same", activation = "relu")(x)#, kernel_initializer = "glorot_normal"
   x = Conv2D(n_filters, 3, padding = "same", activation = "relu")(x)

   return x
def encoder_block(x, n_filters):
   f = double_conv_block(x, n_filters)
   p = MaxPool2D(pool_size =(2,2))(f)
   p = Dropout(0.1)(p)

   return f, p
def decoder_block(x, conv_features, n_filters):
   # upsample/decoder
   x = Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
   x = concatenate([x, conv_features])#concatenate with enconder
   x = Dropout(0.3)(x)
   # Conv2D twice with ReLU activation
   x = double_conv_block(x, n_filters)

   return x
def custom_Unet(shape=(224,224,3),classes=1,activation='sigmoid'):
   # inputs
   inputs = Input(shape=shape)

   # encoder: contracting path - downsample
   # 1 
   f1, p1 = encoder_block(inputs, 32)
   # 2 
   f2, p2 = encoder_block(p1, 64)
   # 3 
   f3, p3 = encoder_block(p2, 64)
   # 4 
   f4, p4 = encoder_block(p3, 128)

   # 5 - bottleneck
   bottleneck = double_conv_block(p4, 512)

   # decoder: expanding path - upsample
   # 6 
   u6 = decoder_block(bottleneck, f4, 128)
   # 7
   u7 = decoder_block(u6, f3, 64)
   # 8
   u8 = decoder_block(u7, f2, 64)
   # 9 
   u9 = decoder_block(u8, f1, 32)

   # outputs
   outputs = Conv2D(classes, 1, padding="same", activation = activation)(u9)

   # unet model with Keras Functional API
   unet_model = tf.keras.Model(inputs, outputs, name="U-Net")

   return unet_model

# %%
unet_model=custom_Unet(shape=(224,224,3),classes=1,activation='sigmoid')
unet_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
unet_model.summary()
# Out:
# Model: "U-Net"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 224, 224, 32)   │            896 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 224, 224, 32)   │          9,248 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 112, 112, 32)   │              0 │ conv2d_1[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 112, 112, 32)   │              0 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 112, 112, 64)   │         18,496 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 112, 112, 64)   │         36,928 │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 56, 56, 64)     │              0 │ conv2d_3[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 56, 56, 64)     │              0 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 56, 56, 64)     │         36,928 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 56, 56, 64)     │         36,928 │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 28, 28, 64)     │              0 │ conv2d_5[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 28, 28, 64)     │              0 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 28, 28, 128)    │         73,856 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 28, 28, 128)    │        147,584 │ conv2d_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 14, 14, 128)    │              0 │ conv2d_7[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 14, 14, 128)    │              0 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 14, 14, 512)    │        590,336 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 14, 14, 512)    │      2,359,808 │ conv2d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 28, 28, 128)    │        589,952 │ conv2d_9[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 28, 28, 256)    │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ conv2d_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 28, 28, 256)    │              0 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 28, 28, 128)    │        295,040 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 28, 28, 128)    │        147,584 │ conv2d_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 56, 56, 64)     │         73,792 │ conv2d_11[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 56, 56, 128)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 56, 56, 128)    │              0 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 56, 56, 64)     │         73,792 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 56, 56, 64)     │         36,928 │ conv2d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 112, 112, 64)   │         36,928 │ conv2d_13[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 112, 112, 128)  │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_6 (Dropout)       │ (None, 112, 112, 128)  │              0 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 112, 112, 64)   │         73,792 │ dropout_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 112, 112, 64)   │         36,928 │ conv2d_14[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 224, 224, 32)   │         18,464 │ conv2d_15[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 224, 224, 64)   │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 224, 224, 64)   │              0 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 224, 224, 32)   │         18,464 │ dropout_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 224, 224, 32)   │          9,248 │ conv2d_16[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 224, 224, 1)    │             33 │ conv2d_17[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 4,721,953 (18.01 MB)
#  Trainable params: 4,721,953 (18.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import plot_model

plot_model(unet_model, to_file='model_structure.png', show_shapes=True, show_layer_names=True)

# %%
checkpoint = ModelCheckpoint(filepath='road_models_custom/modelo-{epoch:02d}-{val_accuracy:.2f}.weights.h5',
                             monitor='val_accuracy',  # Puede ser 'val_accuracy' si prefieres
                             save_best_only=True,
                             save_weights_only=True,  # Para guardar toda la arquitectura y los pesos
                             mode='max',  # O 'max' si monitorizas 'accuracy'
                             verbose=1)

# %% [markdown]
# **Nota:** Debido al alto coste computacional este comando se ha ejecutado desde la GPU de Google Collab, como se ve, ha tardado unos 33min para solo 25 epocas. La verdad que comparado con otros va bastante rápido.

# %%
start=time.time()
history=unet_model.fit(
   x=X_train_pro[:],
   y=Y_train_pro[:].astype(np.float16),
   batch_size=16,
   epochs=25,
   validation_data=(X_test_pro, Y_test_pro.astype(np.float16)),
   callbacks=[checkpoint],
)
print(f'Finalizado en {round(time.time()-start,2)} s')
# Out:
# Epoch 1/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9746 - loss: 0.0720
# Epoch 1: val_accuracy improved from 0.97907 to 0.98037, saving model to road_models_custom/modelo-01-0.98.weights.h5
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 67s 197ms/step - accuracy: 0.9746 - loss: 0.0720 - val_accuracy: 0.9804 - val_loss: 0.0580
# Epoch 2/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9753 - loss: 0.0709
# Epoch 2: val_accuracy did not improve from 0.98037
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 66s 194ms/step - accuracy: 0.9753 - loss: 0.0709 - val_accuracy: 0.9801 - val_loss: 0.0575
# Epoch 3/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9756 - loss: 0.0696
# Epoch 3: val_accuracy did not improve from 0.98037
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 83s 196ms/step - accuracy: 0.9756 - loss: 0.0696 - val_accuracy: 0.9801 - val_loss: 0.0577
# Epoch 4/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9761 - loss: 0.0677
# Epoch 4: val_accuracy did not improve from 0.98037
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 82s 196ms/step - accuracy: 0.9761 - loss: 0.0677 - val_accuracy: 0.9800 - val_loss: 0.0583
# Epoch 5/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9756 - loss: 0.0701
# Epoch 5: val_accuracy improved from 0.98037 to 0.98092, saving model to road_models_custom/modelo-05-0.98.weights.h5
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 82s 197ms/step - accuracy: 0.9756 - loss: 0.0701 - val_accuracy: 0.9809 - val_loss: 0.0567
# Epoch 6/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9766 - loss: 0.0668
# Epoch 6: val_accuracy did not improve from 0.98092
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 82s 199ms/step - accuracy: 0.9766 - loss: 0.0668 - val_accuracy: 0.9803 - val_loss: 0.0588
# Epoch 7/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9767 - loss: 0.0663
# Epoch 7: val_accuracy improved from 0.98092 to 0.98122, saving model to road_models_custom/modelo-07-0.98.weights.h5
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 81s 197ms/step - accuracy: 0.9767 - loss: 0.0663 - val_accuracy: 0.9812 - val_loss: 0.0546
# Epoch 8/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9773 - loss: 0.0651
# Epoch 8: val_accuracy improved from 0.98122 to 0.98137, saving model to road_models_custom/modelo-08-0.98.weights.h5
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 82s 197ms/step - accuracy: 0.9773 - loss: 0.0651 - val_accuracy: 0.9814 - val_loss: 0.0560
# Epoch 9/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9774 - loss: 0.0636
# Epoch 9: val_accuracy improved from 0.98137 to 0.98139, saving model to road_models_custom/modelo-09-0.98.weights.h5
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 83s 200ms/step - accuracy: 0.9774 - loss: 0.0636 - val_accuracy: 0.9814 - val_loss: 0.0548
# Epoch 10/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9774 - loss: 0.0639
# Epoch 10: val_accuracy did not improve from 0.98139
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 81s 197ms/step - accuracy: 0.9774 - loss: 0.0639 - val_accuracy: 0.9812 - val_loss: 0.0542
# Epoch 11/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9781 - loss: 0.0628
# Epoch 11: val_accuracy improved from 0.98139 to 0.98143, saving model to road_models_custom/modelo-11-0.98.weights.h5
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 82s 198ms/step - accuracy: 0.9781 - loss: 0.0628 - val_accuracy: 0.9814 - val_loss: 0.0543
# Epoch 12/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9783 - loss: 0.0615
# Epoch 12: val_accuracy did not improve from 0.98143
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 81s 196ms/step - accuracy: 0.9783 - loss: 0.0615 - val_accuracy: 0.9812 - val_loss: 0.0547
# Epoch 13/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9785 - loss: 0.0603
# Epoch 13: val_accuracy did not improve from 0.98143
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 83s 199ms/step - accuracy: 0.9785 - loss: 0.0603 - val_accuracy: 0.9814 - val_loss: 0.0548
# Epoch 14/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9779 - loss: 0.0625
# Epoch 14: val_accuracy improved from 0.98143 to 0.98173, saving model to road_models_custom/modelo-14-0.98.weights.h5
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 81s 197ms/step - accuracy: 0.9779 - loss: 0.0625 - val_accuracy: 0.9817 - val_loss: 0.0545
# Epoch 15/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9788 - loss: 0.0599
# Epoch 15: val_accuracy improved from 0.98173 to 0.98184, saving model to road_models_custom/modelo-15-0.98.weights.h5
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 82s 197ms/step - accuracy: 0.9788 - loss: 0.0599 - val_accuracy: 0.9818 - val_loss: 0.0541
# Epoch 16/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9791 - loss: 0.0590
# Epoch 16: val_accuracy did not improve from 0.98184
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 82s 199ms/step - accuracy: 0.9791 - loss: 0.0590 - val_accuracy: 0.9805 - val_loss: 0.0573
# Epoch 17/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9792 - loss: 0.0593
# Epoch 17: val_accuracy did not improve from 0.98184
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 81s 196ms/step - accuracy: 0.9792 - loss: 0.0593 - val_accuracy: 0.9816 - val_loss: 0.0555
# Epoch 18/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9793 - loss: 0.0579
# Epoch 18: val_accuracy did not improve from 0.98184
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 82s 196ms/step - accuracy: 0.9793 - loss: 0.0579 - val_accuracy: 0.9815 - val_loss: 0.0550
# Epoch 19/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9789 - loss: 0.0593
# Epoch 19: val_accuracy did not improve from 0.98184
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 83s 199ms/step - accuracy: 0.9789 - loss: 0.0593 - val_accuracy: 0.9812 - val_loss: 0.0562
# Epoch 20/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9790 - loss: 0.0597
# Epoch 20: val_accuracy did not improve from 0.98184
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 82s 199ms/step - accuracy: 0.9790 - loss: 0.0597 - val_accuracy: 0.9817 - val_loss: 0.0581
# Epoch 21/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9793 - loss: 0.0585
# Epoch 21: val_accuracy did not improve from 0.98184
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 82s 198ms/step - accuracy: 0.9793 - loss: 0.0585 - val_accuracy: 0.9810 - val_loss: 0.0570
# Epoch 22/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9795 - loss: 0.0575
# Epoch 22: val_accuracy did not improve from 0.98184
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 82s 199ms/step - accuracy: 0.9795 - loss: 0.0575 - val_accuracy: 0.9814 - val_loss: 0.0559
# Epoch 23/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9793 - loss: 0.0586
# Epoch 23: val_accuracy did not improve from 0.98184
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 66s 197ms/step - accuracy: 0.9793 - loss: 0.0586 - val_accuracy: 0.9816 - val_loss: 0.0555
# Epoch 24/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9799 - loss: 0.0564
# Epoch 24: val_accuracy did not improve from 0.98184
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 83s 199ms/step - accuracy: 0.9799 - loss: 0.0564 - val_accuracy: 0.9810 - val_loss: 0.0563
# Epoch 25/25
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9801 - loss: 0.0555
# Epoch 25: val_accuracy did not improve from 0.98184
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 81s 196ms/step - accuracy: 0.9801 - loss: 0.0555 - val_accuracy: 0.9813 - val_loss: 0.0574
# Finalizado en 2025.99 s

# %%
unet_model.save_weights('road_models_custom/model_final.weights.h5')

# %%
import json

# Guardar el history en un archivo JSON
with open('history.json', 'w') as f:
    json.dump(history.history, f)

# %%
# Obtener los datos de 'loss' y 'accuracy' del objeto history
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history.get('accuracy')  # 'accuracy' es la métrica de precisión
val_accuracy = history.history.get('val_accuracy')  # Precisión en validación

# Crear el gráfico de Loss vs Epochs
plt.figure(figsize=(12, 5))

# Loss
plt.subplot(1, 2, 1)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(accuracy, label='Training Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Mostrar los gráficos
plt.show()

# %% [markdown]
# **Nota:** En este caso si podría ser rentable usar más épocas. Como se ve, la validación funciona mejor que el training, debido seguramente a desbalance entre train y val, ya que tenemos bastantes mas imagenes en training que en validation.

# %%
def plot_images_comparation(list_images_rows,titles_rows=["Input Image", "Real Mask", "Predicted Mask"]):
    num_rows = len(list_images_rows)
    fig=plt.figure(figsize=(15, 5*num_rows))
    index=1
    for i in range(num_rows):
        for j in range(3):
            plt.subplot(num_rows,3,index)
            plt.imshow(list_images_rows[i][j])
            plt.axis('off')
            if i==0:
                plt.title(titles_rows[j])
            index+=1
    plt.show()

# Índices de las imágenes que deseas mostrar agrupadas
max_image=4
# Preparar imágenes y títulos para visualizar en grupos de tres
images_list = []
preds=unet_model.predict(X_val_pro[:4])
pred_binary = (preds > 0.5).astype(np.uint8)
# Agrupar imágenes y títulos en filas de tres
for i in range(0, 4):
    input_image = X_val_pro[i]
    ground_truth_mask = Y_val_pro[i]
    predicted_mask = pred_binary[i]
    images_list.append([input_image, ground_truth_mask, predicted_mask])
plot_images_comparation(images_list)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
def reconstruir_imagen(trozos_imagen,tamano_original,tipo='img'):
    num_cortes=trozos_imagen.shape[0]
    recorte=trozos_imagen.shape[1]
    num_cortes_eje=int(np.sqrt(num_cortes))
    a=np.array([])
    if tipo == 'img':
        a=np.zeros((tamano_original,tamano_original,3))
    elif tipo=='msk':
        if len(trozos_imagen.shape)==3:
            a=np.zeros((tamano_original,tamano_original))
        elif len(trozos_imagen.shape)==4:
            a=np.zeros((tamano_original,tamano_original,1))
    index_tot=0
    for i in range(num_cortes_eje):
        if i!=num_cortes_eje-1:
            corte_ini_x=(i)*recorte
            corte_fin_x=(i+1)*recorte
        else:
            corte_ini_x=tamano_original-recorte
            corte_fin_x=tamano_original
        for j in range(num_cortes_eje):
            #if a.shape[0]==0:
            #    a=trozos_imagen[i]
            #else:
            #    a=np.vstack([a,trozos_imagen[i]])
            #print(a.shape,trozos_imagen[i].shape)
            if j!=num_cortes_eje-1:
                corte_ini_y=(j)*recorte
                corte_fin_y=(j+1)*recorte
            else:
                corte_ini_y=tamano_original-recorte
                corte_fin_y=tamano_original
            if tipo == 'img':
                a[corte_ini_y:corte_fin_y,corte_ini_x:corte_fin_x,:]=trozos_imagen[index_tot]
            elif tipo=='msk':
                if len(trozos_imagen.shape)==3:
                    a[corte_ini_y:corte_fin_y,corte_ini_x:corte_fin_x]=trozos_imagen[index_tot]
                if len(trozos_imagen.shape)==4:
                    a[corte_ini_y:corte_fin_y,corte_ini_x:corte_fin_x,:]=trozos_imagen[index_tot]

            index_tot+=1
    return a

# %% [markdown]
# # Test
# ---

# %%
from sklearn.metrics import accuracy_score,f1_score
model_road=custom_Unet(shape=(224,224,3),classes=1,activation='sigmoid',filters=[32,64,64,128,512,128,64,64,32])
model_road.load_weights('../Trained_models/road_models_custom/modelo-15-0.98.weights.h5')

preds=model_road.predict(X_test_pro)
pred_binary = (preds > 0.5).astype(np.uint8)
y_test_flat = Y_test_pro.flatten()
pred_flat = pred_binary.flatten()
# accuracy
accuracy = accuracy_score(y_test_flat, pred_flat)
print('-'*60)
print('F1: ',round(f1_score(y_test_flat, pred_flat,average='macro'),4),'\nAccuracy: ',round(accuracy,4))
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 638ms/step
# ------------------------------------------------------------
# F1:  0.8423
# Accuracy:  0.9818
